# %%
import pandas as pd
from pathlib import Path
import re

folder_name = "it_company"
file_path = Path(folder_name) / "google_workspace_leads.xlsx"

df = pd.read_excel(file_path)

def split_emails(row):
    """Split rows with multiple emails separated by common delimiters"""
    email_col = 'Email'
    phone_col = 'Phone'  # Adjust if your column name is different
    
    if pd.isna(row[email_col]):
        return [row]
    
    # Split by common delimiters: comma, semicolon, space, pipe
    emails = re.split(r'[,;\s|]+', str(row[email_col]))
    emails = [e.strip() for e in emails if e.strip()]
    
    if len(emails) <= 1:
        return [row]
    
    # Create duplicate rows for each email
    rows = []
    for i, email in enumerate(emails):
        new_row = row.copy()
        new_row[email_col] = email
        # Keep phone number only for the first row, clear it for duplicates
        if i > 0:
            new_row[phone_col] = None  # or '' for empty string
        rows.append(new_row)
    return rows

# Apply the splitting function
expanded_rows = []
for _, row in df.iterrows():
    expanded_rows.extend(split_emails(row))

df = pd.DataFrame(expanded_rows).reset_index(drop=True)

def extract_business_name(name):
    """Extract the first part of business name before - or |"""
    if pd.isna(name):
        return name
    name = str(name)
    # Split by - or | and take the first part
    parts = re.split(r'\s*[-|:–,/]\s*|\s+I\s+', name)
    return parts[0].strip()

df['Name'] = df['Name'].apply(extract_business_name)

def is_sentry_email(email):
    """Check if email matches sentry pattern"""
    if pd.isna(email):
        return False
    email = str(email).lower()
    # Pattern: 32 hex characters @ sentry domains
    pattern = r'^[a-f0-9]{32}@sentry.*\.(wixpress\.com|io)$'
    return bool(re.match(pattern, email))

# Filter out sentry emails
df = df[~df['Email'].apply(is_sentry_email)].reset_index(drop=True)

print(f"Rows before removing duplicates: {len(df)}")
df = df.drop_duplicates(subset=['Name', 'Email'], keep='first').reset_index(drop=True)
print(f"Rows after removing duplicates: {len(df)}")

# Display results
print(f"\nTotal rows after processing: {len(df)}")
print("\nFirst few rows:")
print(df.head(10))

# Save to new Excel file
new_file_path= Path(folder_name) / "google_workspace_cleaned_leads.xlsx"

df.to_excel(new_file_path, index=False)
print("\nData saved to 'cleaned_data.xlsx'")
# Out:
# Rows before removing duplicates: 554
# Rows after removing duplicates: 351
#
# Total rows after processing: 351
#
# First few rows:
#                                                  URL    Industry  \
# 0  https://www.google.com/maps/place/Bitcot/data=...  IT company
# 1  https://www.google.com/maps/place/Full+Circle+...  IT company
# 2  https://www.google.com/maps/place/Internet+Sof...  IT company
# 3  https://www.google.com/maps/place/Internet+Sof...  IT company
# 4  https://www.google.com/maps/place/Info+Web+USA...  IT company
# 5  https://www.google.com/maps/place/The+Neat+Com...  IT company
# 6  https://www.google.com/maps/place/TekRevol+Hou...  IT company
# 7  https://www.google.com/maps/place/Sikka+Softwa...  IT company
# 8  https://www.google.com/maps/place/TechGropse+L...  IT company
# 9  https://www.google.com/maps/place/210+IT/data=...  IT company
#
#                          Name                            Email  \
# 0                      Bitcot               support@bitcot.com
# 1    Full Circle AI Solutions  Brandon@full-circle-systems.com
# 2               Internet Soft           sales@internetsoft.com
# 3               Internet Soft         support@internetsoft.com
# 4   Info Web USA Technologies           connect@infowebusa.com
# 5            The Neat Company                              NaN
# 6            TekRevol Houston                info@tekrevol.com
# 7  Sikka Software Corporation                    info@sikka.ai
# 8      TechGropse Los Angeles              info@techgropse.com
# 9                      210 IT                              NaN
#
#                                              Address CountryCode  \
# 0  16870 W Bernardo Dr #400, San Diego, CA 92127,...          US
# 1  8210 Shooting Quail, San Antonio, TX 78250, Un...          US
# 2  6203 San Ignacio Ave #110, San Jose, CA 95119,...          US
# 3  6203 San Ignacio Ave #110, San Jose, CA 95119,...          US
# 4  5100 Wilshire Blvd, Los Angeles, CA 90036, Uni...          US
# 5  1515 Market St #1200, Philadelphia, PA 19102, ...          US
# 6  4201 Main St Suite # 200-122, Houston, TX 7700...          US
# 7  2870 Zanker Rd Suite 120, San Jose, CA 95134, ...          US
# 8  6080 Center Dr W, Los Angeles, CA 90045, Unite...          US
# 9  4706 Shavano Oak #102, San Antonio, TX 78249, ...          US
#
#           Phone                                            Website  Rating  \
# 0  1.858683e+10                            https://www.bitcot.com/     5.0
# 1  1.210324e+10     https://full-circle-systems.com/home-7363-6252     5.0
# 2  1.305736e+10  https://internetsoft.com/software-development-...     4.9
# 3           NaN  https://internetsoft.com/software-development-...     4.9
# 4  1.213757e+10                         http://www.infowebusa.com/     4.8
# 5  1.866633e+10                               http://www.neat.com/     4.6
# 6  1.281477e+10  https://www.tekrevol.com/?utm_source=gmb&utm_m...     4.6
# 7  1.408876e+10                              https://www.sikka.ai/     4.9
# 8  1.267327e+10  https://www.techgropse.com/mobile-app-developm...     4.6
# 9  1.210499e+10                              http://www.210it.com/     5.0
#
#    InfoCode                                    InfoMatrix EmailProvider  \
# 0    111111  name, email, address, phone, website, rating        google
# 1    111111  name, email, address, phone, website, rating        google
# 2    111111  name, email, address, phone, website, rating        google
# 3    111111  name, email, address, phone, website, rating        google
# 4    111111  name, email, address, phone, website, rating        google
# 5    101111         name, address, phone, website, rating        google
# 6    111111  name, email, address, phone, website, rating        google
# 7    111111  name, email, address, phone, website, rating        google
# 8    111111  name, email, address, phone, website, rating        google
# 9    101111         name, address, phone, website, rating        google
#
#                                            MXRecords
# 0  aspmx.l.google.com, alt3.aspmx.l.google.com, a...
# 1  aspmx.l.google.com, alt1.aspmx.l.google.com, a...
# 2  aspmx.l.google.com, alt3.aspmx.l.google.com, a...
# 3  aspmx.l.google.com, alt3.aspmx.l.google.com, a...
# 4  aspmx.l.google.com, alt3.aspmx.l.google.com, a...
# 5                                    smtp.google.com
# 6  aspmx.l.google.com, alt3.aspmx.l.google.com, a...
# 7  aspmx.l.google.com, alt1.aspmx.l.google.com, a...
# 8  aspmx.l.google.com, alt3.aspmx.l.google.com, a...
# 9  aspmx.l.google.com, alt1.aspmx.l.google.com, a...
#
# Data saved to 'cleaned_data.xlsx'
