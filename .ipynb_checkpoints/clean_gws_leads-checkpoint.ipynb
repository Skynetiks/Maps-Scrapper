# %%
import pandas as pd
import re

# %%
df = pd.read_excel('microsoft_outlook_leads.xlsx')

# %%
def split_emails(row):
    """Split rows with multiple emails separated by common delimiters"""
    email_col = 'Email'
    
    if pd.isna(row[email_col]):
        return [row]
    
    # Split by common delimiters: comma, semicolon, space, pipe
    emails = re.split(r'[,;\s|]+', str(row[email_col]))
    emails = [e.strip() for e in emails if e.strip()]
    
    if len(emails) <= 1:
        return [row]
    
    # Create duplicate rows for each email
    rows = []
    for email in emails:
        new_row = row.copy()
        new_row[email_col] = email
        rows.append(new_row)
    return rows

# Apply the splitting function
expanded_rows = []
for _, row in df.iterrows():
    expanded_rows.extend(split_emails(row))

df = pd.DataFrame(expanded_rows).reset_index(drop=True)

# %%
def extract_business_name(name):
    """Extract the first part of business name before - or |"""
    if pd.isna(name):
        return name
    name = str(name)
    # Split by - or | and take the first part
    parts = re.split(r'\s*[-|]\s*', name)
    return parts[0].strip()

df['Name'] = df['Name'].apply(extract_business_name)

# %%
def is_sentry_email(email):
    """Check if email matches sentry pattern"""
    if pd.isna(email):
        return False
    email = str(email).lower()
    # Pattern: 32 hex characters @ sentry domains
    pattern = r'^[a-f0-9]{32}@sentry.*\.(wixpress\.com|io)$'
    return bool(re.match(pattern, email))

# Filter out sentry emails
df = df[~df['Email'].apply(is_sentry_email)].reset_index(drop=True)

# %%
print(f"Rows before removing duplicates: {len(df)}")
df = df.drop_duplicates(subset=['Name', 'Email'], keep='first').reset_index(drop=True)
print(f"Rows after removing duplicates: {len(df)}")

# Display results
print(f"\nTotal rows after processing: {len(df)}")
print("\nFirst few rows:")
print(df.head(10))
# Out:
# Rows before removing duplicates: 129
# Rows after removing duplicates: 19
#
# Total rows after processing: 19
#
# First few rows:
#                                                  URL            Industry  \
# 0  https://www.google.com/maps/place/AutoAid/data...  Automotive Service
# 1  https://www.google.com/maps/place/myTVS+-+Car+...  Automotive Service
# 2  https://www.google.com/maps/place/GoMechanic+-...  Automotive Service
# 3  https://www.google.com/maps/place/GoMechanic+L...  Automotive Service
# 4  https://www.google.com/maps/place/A2z+Car+Care...  Automotive Service
# 5  https://www.google.com/maps/place/MyTVS+Car+Se...  Automotive Service
# 6  https://www.google.com/maps/place/Castrol+Serv...  Automotive Service
# 7  https://www.google.com/maps/place/7th+Gear+Aut...  Automotive Service
# 8  https://www.google.com/maps/place/Petromin+-+K...  Automotive Service
# 9  https://www.google.com/maps/place/Castrol+Auto...  Automotive Service
#
#                              Name                        Email  \
# 0                         AutoAid              info@autoaid.in
# 1                           myTVS       customer.help@mytvs.in
# 2                      GoMechanic           info@gomechanic.in
# 3                 GoMechanic Luxe           info@gomechanic.in
# 4            A2z Car Care Service                          NaN
# 5  MyTVS Car Services OMR Chennai       customer.help@mytvs.in
# 6                 Castrol Service                          NaN
# 7         7th Gear Automotive LLp           info@gomechanic.in
# 8                        Petromin  customercare.pe@petromin.in
# 9            Castrol Auto Service                          NaN
#
#                                              Address CountryCode  \
# 0  Bldg No: 1604, 2nd Floor, 25th Main, 22nd Cros...          IN
# 1  Mahal Road, near Jagatpura Railway Crossing, R...          IN
# 2  1st Floor, Sony World Signal, 100 Feet Rd, Ven...          IN
# 3  5, Lokenath Bose Garden Lane, Gobinda Khatick ...          IN
# 4  a2z car care Garage, Synergy Office Spaces, Ea...          IN
# 5  Plot No:62 & 63, Bethel Nagar, Rajiv Gandhi Sa...          IN
# 6  Bus Stand, Badarna Rd, Vishwakarma Industrial ...          IN
# 7  Madhapur Rd, Kakatiya Hills, Guttala_Begumpet,...          IN
# 8  6, Kasturba Rd, Ambedkar Veedhi, Bengaluru, Ka...          IN
# 9  Plot No 317,318, Sairam Industrial, Bamroli - ...          IN
#
#           Phone                                            Website  Rating  \
# 0  7.353735e+09                                https://autoaid.in/     4.8
# 1  7.358202e+09  https://mytvs.in/Service?utm_source=Google&utm...     4.7
# 2  8.398971e+09                             https://gomechanic.in/     4.4
# 3  9.319927e+09                             https://gomechanic.in/     4.3
# 4  8.530114e+09                        https://www.a2zcarcare.com/     4.9
# 5  7.358202e+09  https://mytvs.in/Service?utm_source=Google&utm...     4.1
# 6  9.799139e+09  https://www.castrol.com/en_in/india/home.html?...     5.0
# 7  7.799872e+09                             https://gomechanic.in/     4.5
# 8  8.686892e+09                               https://petromin.in/     4.8
# 9  9.377720e+09  https://www.castrol.com/?utm_source=locator&ut...     5.0
#
#    InfoCode                                    InfoMatrix EmailProvider  \
# 0    111111  name, email, address, phone, website, rating     microsoft
# 1    111111  name, email, address, phone, website, rating     microsoft
# 2    111111  name, email, address, phone, website, rating     microsoft
# 3    111111  name, email, address, phone, website, rating     microsoft
# 4    101111         name, address, phone, website, rating     microsoft
# 5    111111  name, email, address, phone, website, rating     microsoft
# 6    101111         name, address, phone, website, rating     microsoft
# 7    111111  name, email, address, phone, website, rating     microsoft
# 8    111111  name, email, address, phone, website, rating     microsoft
# 9    101111         name, address, phone, website, rating     microsoft
#
#                                            MXRecords
# 0             autoaid-in.mail.protection.outlook.com
# 1               mytvs-in.mail.protection.outlook.com
# 2          gomechanic-in.mail.protection.outlook.com
# 3          gomechanic-in.mail.protection.outlook.com
# 4         a2zcarcare-com.mail.protection.outlook.com
# 5               mytvs-in.mail.protection.outlook.com
# 6  castrol-com.mail.protection.outlook.com, castr...
# 7          gomechanic-in.mail.protection.outlook.com
# 8            petromin-in.mail.protection.outlook.com
# 9  castrol-com.mail.protection.outlook.com, castr...

# %%
# Save to new Excel file
df.to_excel('microsoft_outlook_leads.xlsx', index=False)
print("\nData saved to 'cleaned_data.xlsx'")
# Out:
# Data saved to 'cleaned_data.xlsx'
