# %%
import pandas as pd
import re

# Read the Excel file
df = pd.read_excel('automotive_service/other_providers_leads.xlsx')

# 1. Create duplicate rows for any row having more than 1 email id
def split_emails(row):
    """Split rows with multiple emails separated by common delimiters"""
    email_col = 'Email'
    
    if pd.isna(row[email_col]):
        return [row]
    
    # Split by common delimiters: comma, semicolon, space, pipe
    emails = re.split(r'[,;\s|]+', str(row[email_col]))
    emails = [e.strip() for e in emails if e.strip()]
    
    if len(emails) <= 1:
        return [row]
    
    # Create duplicate rows for each email
    rows = []
    for email in emails:
        new_row = row.copy()
        new_row[email_col] = email
        rows.append(new_row)
    return rows

# Apply the splitting function
expanded_rows = []
for _, row in df.iterrows():
    expanded_rows.extend(split_emails(row))

df = pd.DataFrame(expanded_rows).reset_index(drop=True)

# 2. Save business name's first part using - or | as delimiter
def extract_business_name(name):
    """Extract the first part of business name before - or |"""
    if pd.isna(name):
        return name
    name = str(name)
    # Split by - or | and take the first part
parts = re.split(r'\s*[-|:–]\s*', name)    return parts[0].strip()

df['Name'] = df['Name'].apply(extract_business_name)

# 3. Filter out email records matching the sentry pattern
def is_sentry_email(email):
    """Check if email matches sentry pattern"""
    if pd.isna(email):
        return False
    email = str(email).lower()
    # Pattern: 32 hex characters @ sentry domains
    pattern = r'^[a-f0-9]{32}@sentry.*\.(wixpress\.com|io)$'
    return bool(re.match(pattern, email))

# Filter out sentry emails
df = df[~df['Email'].apply(is_sentry_email)].reset_index(drop=True)

# 4. Remove duplicate rows with same Name and Email
print(f"Rows before removing duplicates: {len(df)}")
df = df.drop_duplicates(subset=['Name', 'Email'], keep='first').reset_index(drop=True)
print(f"Rows after removing duplicates: {len(df)}")

# 5. Filter out Zoho users
def is_zoho_user(row):
    """Check if the lead uses Zoho MX records"""
    mx_col = 'MXRecords'  # Adjust column name if different
    
    if pd.isna(row[mx_col]):
        return False
    
    mx_records = str(row[mx_col]).lower()
    # Check if MX records contain zoho
    return 'zoho.com' in mx_records

zoho_count = df[df.apply(is_zoho_user, axis=1)].shape[0]
print(f"\nFiltering out {zoho_count} Zoho users...")
df = df[~df.apply(is_zoho_user, axis=1)].reset_index(drop=True)

# 6. Separate Hostinger leads
def is_hostinger_lead(row):
    """Check if the lead uses Hostinger MX records"""
    mx_col = 'MXRecords'  # Adjust column name if different
    
    if pd.isna(row[mx_col]):
        return False
    
    mx_records = str(row[mx_col]).lower()
    # Check if MX records contain hostinger
    return 'hostinger' in mx_records

# Split into Hostinger and non-Hostinger leads
hostinger_df = df[df.apply(is_hostinger_lead, axis=1)].reset_index(drop=True)
other_df = df[~df.apply(is_hostinger_lead, axis=1)].reset_index(drop=True)

# Display results
print(f"\n=== SUMMARY ===")
print(f"Total Hostinger leads: {len(hostinger_df)}")
print(f"Total other leads (excluding Zoho): {len(other_df)}")
print(f"Total leads (excluding Zoho): {len(df)}")

print("\n=== First few Hostinger leads ===")
print(hostinger_df.head(10))

print("\n=== First few other leads ===")
print(other_df.head(10))

# Save to separate Excel files
hostinger_df.to_excel('hostinger_leads.xlsx', index=False)
other_df.to_excel('other_provider_leads.xlsx', index=False)
# df.to_excel('all_cleaned_leads.xlsx', index=False)

print("\n=== Files saved ===")
print("✓ hostinger_leads.xlsx - Contains all Hostinger leads")
print("✓ other_leads.xlsx - Contains all non-Hostinger, non-Zoho leads")
print("✓ all_cleaned_leads.xlsx - Contains all cleaned leads (excluding Zoho)")
# Out:
# Rows before removing duplicates: 1138
# Rows after removing duplicates: 965
#
# Filtering out 5 Zoho users...
#
# === SUMMARY ===
# Total Hostinger leads: 41
# Total other leads (excluding Zoho): 919
# Total leads (excluding Zoho): 960
#
# === First few Hostinger leads ===
#                                                  URL            Industry  \
# 0  https://www.google.com/maps/place/YES+MOTOR+BO...  Automotive Service
# 1  https://www.google.com/maps/place/YES+MOTOR+BO...  Automotive Service
# 2  https://www.google.com/maps/place/11+MOTORS+%7...  Automotive Service
# 3  https://www.google.com/maps/place/Aman+Motor+W...  Automotive Service
# 4  https://www.google.com/maps/place/Galaxy+Auto+...  Automotive Service
# 5  https://www.google.com/maps/place/Galaxy+Auto+...  Automotive Service
# 6  https://www.google.com/maps/place/Welltech+Mot...  Automotive Service
# 7  https://www.google.com/maps/place/Infinity+Car...  Automotive Service
# 8  https://www.google.com/maps/place/Samruddhi+Ca...  Automotive Service
# 9  https://www.google.com/maps/place/Wrench+Dynas...  Automotive Service
#
#                                        Name                         Email  \
# 0  YES MOTOR BOSCH Car Service in Bangalore             info@yesmotor.com
# 1  YES MOTOR BOSCH Car Service in Bangalore        yesmotor.blr@gmail.com
# 2                                 11 MOTORS             info@11motors.com
# 3                          Aman Motor Works      amanmotorworks@gmail.com
# 4                         Galaxy Auto Works      info@galaxyautoworks.com
# 5                         Galaxy Auto Works  services@galaxyautoworks.com
# 6                           Welltech Motors       info@welltechmotors.com
# 7                     Infinity Car Workshop     chavadibasu6555@gmail.com
# 8                        Samruddhi Car Care  contact@samruddhicarcare.com
# 9                            Wrench Dynasty       wrenchdynasty@kpa.co.in
#
#                                              Address CountryCode  \
# 0  YES MOTOR, ( BOSCH CAR SERVICE, 7th Cross Road...          IN
# 1  YES MOTOR, ( BOSCH CAR SERVICE, 7th Cross Road...          IN
# 2  Gate No. 1 & 2, Between Stadium, Salt Lake Sta...          IN
# 3  Jaihind Water Tank, 13, Arupota Rd, Dhapa, Kol...          IN
# 4  18, Genuine House, Genuine Engineering Works C...          IN
# 5  18, Genuine House, Genuine Engineering Works C...          IN
# 6  Puna Kumbhariya Rd, opp. New Sardar Market, ne...          IN
# 7  Survey no 14 near the one society, opp. to hee...          IN
# 8  No.31, Metro Station 1, Tumkur Rd, Peenya II P...          IN
# 9  E 197, SFS Manasarovar, Hans Vihar, RIICO Indu...          IN
#
#           Phone                                     Website  Rating  InfoCode  \
# 0  7.204444e+09                        https://yesmotor.in/     4.6    111111
# 1  7.204444e+09                        https://yesmotor.in/     4.6    111111
# 2  9.339110e+09                   https://www.11motors.com/     4.8    111111
# 3  9.831122e+09                  https://amanmotorworks.in/     4.1    111111
# 4  9.820225e+09            https://www.galaxyautoworks.com/     4.7    111111
# 5  9.820225e+09            https://www.galaxyautoworks.com/     4.7    111111
# 6  9.824112e+09                  http://welltechmotors.com/     4.9    111111
# 7  9.921927e+09  https://tapvcard.com/infinity-car-workshop     4.9    111111
# 8  8.217519e+09            http://www.samruddhicarcare.com/     4.7    111111
# 9  6.350613e+09                   https://wrenchdynasty.in/     4.9    111111
#
#                                      InfoMatrix EmailProvider  \
# 0  name, email, address, phone, website, rating         other
# 1  name, email, address, phone, website, rating         other
# 2  name, email, address, phone, website, rating         other
# 3  name, email, address, phone, website, rating         other
# 4  name, email, address, phone, website, rating         other
# 5  name, email, address, phone, website, rating         other
# 6  name, email, address, phone, website, rating         other
# 7  name, email, address, phone, website, rating         other
# 8  name, email, address, phone, website, rating         other
# 9  name, email, address, phone, website, rating         other
#
#                               MXRecords
# 0    mx1.hostinger.in, mx2.hostinger.in
# 1    mx1.hostinger.in, mx2.hostinger.in
# 2  mx2.hostinger.com, mx1.hostinger.com
# 3  mx1.hostinger.com, mx2.hostinger.com
# 4  mx1.hostinger.com, mx2.hostinger.com
# 5  mx1.hostinger.com, mx2.hostinger.com
# 6  mx2.hostinger.com, mx1.hostinger.com
# 7    mx1.hostinger.in, mx2.hostinger.in
# 8    mx1.hostinger.in, mx2.hostinger.in
# 9    mx2.hostinger.in, mx1.hostinger.in
#
# === First few other leads ===
#                                                  URL            Industry  \
# 0  https://www.google.com/maps/place/A2Z+Car+Bike...  Automotive Service
# 1  https://www.google.com/maps/place/Azad+Car+Rep...  Automotive Service
# 2  https://www.google.com/maps/place/Tarun+Motors...  Automotive Service
# 3  https://www.google.com/maps/place/Automanic+-+...  Automotive Service
# 4  https://www.google.com/maps/place/Automanic+-+...  Automotive Service
# 5  https://www.google.com/maps/place/Motormechs+A...  Automotive Service
# 6  https://www.google.com/maps/place/Maharashtra+...  Automotive Service
# 7  https://www.google.com/maps/place/Mechanic+Ass...  Automotive Service
# 8  https://www.google.com/maps/place/Dev+Automoti...  Automotive Service
# 9  https://www.google.com/maps/place/Dev+Multi+Ca...  Automotive Service
#
#                                                 Name  \
# 0            A2Z Car Bike[ Door Step Repair Service]
# 1                           Azad Car Repair workshop
# 2                                       Tarun Motors
# 3                                          Automanic
# 4                                          Automanic
# 5                               Motormechs Auto Zone
# 6                             Maharashtra Automobile
# 7                                   Mechanic Assists
# 8  Dev Automotives (Car Automobile Repair & Servi...
# 9                     Dev Multi Car Repair & Service
#
#                           Email  \
# 0             noemail@gmail.com
# 1                           NaN
# 2                           NaN
# 3    info@automanicmotocare.com
# 4   info@automanbicmotocare.com
# 5  motormechsautozone@gmail.com
# 6                           NaN
# 7    contact@mechanicassists.in
# 8                           NaN
# 9                           NaN
#
#                                              Address CountryCode  \
# 0  292, Shop, 10+Years in Business, No.1, 10 Main...          IN
# 1  Shop No 2, Mirza Ismail Rd, near natha arts, P...          IN
# 2  G2 , G3, Siddhachal Avenue, Galleria St, near ...          IN
# 3  14, Arupota Rd, Bosetala, Dhapa, Kolkata, West...          IN
# 4  14, Arupota Rd, Bosetala, Dhapa, Kolkata, West...          IN
# 5  Sr. No. 54/1/9, Mundhwa - Kharadi Rd, near Rai...          IN
# 6  Shop No. 3 Ram Mandir West Behind sunteck City...          IN
# 7  13, 3rd Cross, Tavarekere Main Rd, Cashier Lay...          IN
# 8  Road, Vaishali, 31, Gandhi Path, Deepak Watika...          IN
# 9  near GYM HOUSE, opp. Naginawadi society, New P...          IN
#
#           Phone                                      Website  Rating  \
# 0  9.742786e+09  https://a2z-ysmzb-rp801-app.openweaver.com/     4.9
# 1  9.680654e+09                https://azadcarrepair.in.net/     4.9
# 2  9.825126e+09                 https://www.tarunmotors.com/     4.6
# 3  8.017099e+09                http://automanicmotocare.com/     4.6
# 4  8.017099e+09                http://automanicmotocare.com/     4.6
# 5  7.350913e+09              https://motormechsautozone.com/     4.7
# 6  9.372195e+09                                          NaN     4.9
# 7  9.538381e+09                   http://mechanicassists.in/     4.9
# 8  9.829886e+09                                          NaN     4.6
# 9  7.878767e+09         https://wa.me/message/U2YETPH7VQA5K1     4.9
#
#    InfoCode                                    InfoMatrix EmailProvider  \
# 0    111111  name, email, address, phone, website, rating         other
# 1    101111         name, address, phone, website, rating         other
# 2    101111         name, address, phone, website, rating         other
# 3    111111  name, email, address, phone, website, rating         other
# 4    111111  name, email, address, phone, website, rating         other
# 5    111111  name, email, address, phone, website, rating         other
# 6    101101                  name, address, phone, rating         other
# 7    111111  name, email, address, phone, website, rating         other
# 8    101101                  name, address, phone, rating         other
# 9    101111         name, address, phone, website, rating         other
#
#                               MXRecords
# 0                                   NaN
# 1                                   NaN
# 2  mx2.zoho.in, mx.zoho.in, mx3.zoho.in
# 3                 automanicmotocare.com
# 4                 automanicmotocare.com
# 5                                   NaN
# 6                                   NaN
# 7               mail.mechanicassists.in
# 8                                   NaN
# 9                                   NaN
#
# === Files saved ===
# ✓ hostinger_leads.xlsx - Contains all Hostinger leads
# ✓ other_leads.xlsx - Contains all non-Hostinger, non-Zoho leads
# ✓ all_cleaned_leads.xlsx - Contains all cleaned leads (excluding Zoho)
