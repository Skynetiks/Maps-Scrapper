# %%
import pandas as pd
import re

df = pd.read_excel('digital_marketing/google_workspace_leads.xlsx')

def split_emails(row):
    """Split rows with multiple emails separated by common delimiters"""
    email_col = 'Email'
    
    if pd.isna(row[email_col]):
        return [row]
    
    # Split by common delimiters: comma, semicolon, space, pipe
    emails = re.split(r'[,;\s|]+', str(row[email_col]))
    emails = [e.strip() for e in emails if e.strip()]
    
    if len(emails) <= 1:
        return [row]
    
    # Create duplicate rows for each email
    rows = []
    for email in emails:
        new_row = row.copy()
        new_row[email_col] = email
        rows.append(new_row)
    return rows

# Apply the splitting function
expanded_rows = []
for _, row in df.iterrows():
    expanded_rows.extend(split_emails(row))

df = pd.DataFrame(expanded_rows).reset_index(drop=True)

def extract_business_name(name):
    """Extract the first part of business name before - or |"""
    if pd.isna(name):
        return name
    name = str(name)
    # Split by - or | and take the first part
    parts = re.split(r'\s*[-|:–,]\s*|\s+I\s+', name)
    return parts[0].strip()

df['Name'] = df['Name'].apply(extract_business_name)

def is_sentry_email(email):
    """Check if email matches sentry pattern"""
    if pd.isna(email):
        return False
    email = str(email).lower()
    # Pattern: 32 hex characters @ sentry domains
    pattern = r'^[a-f0-9]{32}@sentry.*\.(wixpress\.com|io)$'
    return bool(re.match(pattern, email))

# Filter out sentry emails
df = df[~df['Email'].apply(is_sentry_email)].reset_index(drop=True)

print(f"Rows before removing duplicates: {len(df)}")
df = df.drop_duplicates(subset=['Name', 'Email'], keep='first').reset_index(drop=True)
print(f"Rows after removing duplicates: {len(df)}")

# Display results
print(f"\nTotal rows after processing: {len(df)}")
print("\nFirst few rows:")
print(df.head(10))

# Save to new Excel file
df.to_excel('digital_marketing/google_workspace_leads.xlsx', index=False)
print("\nData saved to 'cleaned_data.xlsx'")
# Out:
# Rows before removing duplicates: 491
# Rows after removing duplicates: 491
#
# Total rows after processing: 491
#
# First few rows:
#                                                  URL          Industry  \
# 0  https://www.google.com/maps/place/Social+101/d...  Marketing Agency
# 1  https://www.google.com/maps/place/Digital+i360...  Marketing Agency
# 2  https://www.google.com/maps/place/The+Cogent+-...  Marketing Agency
# 3  https://www.google.com/maps/place/Digital+Cors...  Marketing Agency
# 4  https://www.google.com/maps/place/Digital+Cors...  Marketing Agency
# 5  https://www.google.com/maps/place/Ad2brand+Dig...  Marketing Agency
# 6  https://www.google.com/maps/place/Dev+Opus+Pvt...  Marketing Agency
# 7  https://www.google.com/maps/place/Dev+Opus+Pvt...  Marketing Agency
# 8  https://www.google.com/maps/place/SHOUT+IN+%26...  Marketing Agency
# 9  https://www.google.com/maps/place/DigitalZap+%...  Marketing Agency
#
#                                                 Name                   Email  \
# 0                                         Social 101      hello@social101.in
# 1                                       Digital i360    info@digitali360.com
# 2                                         The Cogent         hr@thecogent.in
# 3                                     Digital Corsel  info@digitalcorsel.com
# 4                                     Digital Corsel    info@digitali360.com
# 5  Ad2brand Digital Marketing Agency & Digital Ma...                     NaN
# 6                                   Dev Opus Pvt Ltd        info@devopus.com
# 7                                   Dev Opus Pvt Ltd    info@devcreation.com
# 8                                     SHOUT IN & OUT       engitech@mail.com
# 9                                         DigitalZap   contact@digitalzap.in
#
#                                              Address CountryCode  \
# 0  607 - 608, Titaanium Business Hub, Bhimrad-Alt...          IN
# 1  2nd Floor, SS Plaza, Plot No. 12A, Greenland C...          IN
# 2  Shri Anand Vihar, A-46-A, Vande Mataram Marg, ...          IN
# 3  Brahans Business Park, 303, Paper Box Rd, M.I....          IN
# 4  Brahans Business Park, 303, Paper Box Rd, M.I....          IN
# 5  SR NO, 228/5/4, nr. MANGALYA APT, Vishnu Dev N...          IN
# 6  Chase House, Sheetal Baug Society, 202, Chiman...          IN
# 7  Chase House, Sheetal Baug Society, 202, Chiman...          IN
# 8  Kailas Esplanade, C- 418, opposite Vijay Sales...          IN
# 9  Plot No: 32 Road No 1, Nagarjuna Hills Rd, Ban...          IN
#
#           Phone                                            Website  Rating  \
# 0  8.879564e+09                              https://social101.in/     4.6
# 1  8.599002e+09                           https://digitali360.com/     5.0
# 2  9.785958e+09                              https://thecogent.in/     4.8
# 3  8.019998e+09                  https://digitalcorsel.com/mumbai/     4.9
# 4  8.019998e+09                  https://digitalcorsel.com/mumbai/     4.9
# 5  8.208424e+09                          https://www.ad2brand.com/     4.8
# 6  9.904511e+09  https://devopus.com/?utm_source=GMB_Listing&ut...     4.9
# 7  9.904511e+09  https://devopus.com/?utm_source=GMB_Listing&ut...     4.9
# 8  7.021838e+09                         https://shoutinandout.com/     4.9
# 9  7.331123e+09                             https://digitalzap.in/     4.8
#
#    InfoCode                                    InfoMatrix EmailProvider  \
# 0    111111  name, email, address, phone, website, rating        google
# 1    111111  name, email, address, phone, website, rating        google
# 2    111111  name, email, address, phone, website, rating        google
# 3    111111  name, email, address, phone, website, rating        google
# 4    111111  name, email, address, phone, website, rating        google
# 5    101111         name, address, phone, website, rating        google
# 6    111111  name, email, address, phone, website, rating        google
# 7    111111  name, email, address, phone, website, rating        google
# 8    111111  name, email, address, phone, website, rating        google
# 9    111111  name, email, address, phone, website, rating        google
#
#                                            MXRecords
# 0  alt3.aspmx.l.google.com, alt1.aspmx.l.google.c...
# 1  alt3.aspmx.l.google.com, smtp.google.com, alt4...
# 2  alt4.aspmx.l.google.com, aspmx.l.google.com, a...
# 3  alt4.aspmx.l.google.com, aspmx.l.google.com, a...
# 4  alt4.aspmx.l.google.com, aspmx.l.google.com, a...
# 5  alt2.aspmx.l.google.com, aspmx.l.google.com, a...
# 6  alt2.aspmx.l.google.com, aspmx.l.google.com, a...
# 7  alt2.aspmx.l.google.com, aspmx.l.google.com, a...
# 8  alt4.aspmx.l.google.com, alt3.aspmx.l.google.c...
# 9  aspmx.l.google.com, alt3.aspmx.l.google.com, a...
#
# Data saved to 'cleaned_data.xlsx'
